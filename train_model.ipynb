# %%
# Find GPU
import torch

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda:0'

# %%
# Ensure GPU connection for Yolov8
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.210  Python-3.11.5 torch-2.1.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3070, 8192MiB)
# Setup complete  (16 CPUs, 31.9 GB RAM, 203.7/930.8 GB disk)

# %%
# Train the model
from ultralytics import YOLO

# Load a pretrained YOLO model (recommended for training)
model = YOLO('yolov8m.pt')

# Train the model using the 'coco128.yaml' dataset for 3 epochs
results = model.train(data="datasets/taco/taco.yaml", epochs=600)
# Out:
# New https://pypi.org/project/ultralytics/8.0.215 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.210  Python-3.11.5 torch-2.1.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3070, 8192MiB)
# ...

# %%
# Testing with jpg
from PIL import Image
from ultralytics import YOLO

# Load a model
model = YOLO('runs/detect/train/weights/best.pt')  # load a custom model

# Predict with the model
results = model('datasets/taco/test/images/000000_jpg.rf.1b029d4c742673020fa91367070f5f51.jpg')  # predict on an image

for r in results:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    im.show()  # show image
    im.save('results.jpg')  # save image
# Out:
# image 1/1 C:\Users\ethan\PycharmProjects\Yolov8_TCL\datasets\taco\test\images\000000_jpg.rf.1b029d4c742673020fa91367070f5f51.jpg: 640x640 1 Bottle cap, 1 Bottle, 1 Other plastic, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
